# %% [markdown]
# <a href="https://colab.research.google.com/github/lotnay/BSIS_3A/blob/main/jm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Load dataset
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Features and target
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
target = 'Survived'

# %%
# Imputation for continuous data
imputer_mean = SimpleImputer(strategy='mean')
df['Age'] = imputer_mean.fit_transform(df[['Age']])

# %%
imputer_median = SimpleImputer(strategy='median')
df['Fare'] = imputer_median.fit_transform(df[['Fare']])

# %%
# Imputation for categorical data (most frequent)
imputer_mode = SimpleImputer(strategy='most_frequent')
df['Embarked'] = imputer_mode.fit_transform(df[['Embarked']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3f9a7156fcb0> in <cell line: 3>()
#       1 # Imputation for categorical data (most frequent)
#       2 imputer_mode = SimpleImputer(strategy='most_frequent')
# ----> 3 df['Embarked'] = imputer_mode.fit_transform(df[['Embarked']])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5265         if is_list_like(value):
#    5266             com.require_length_match(value, self.index)
# -> 5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#    5269             isinstance(value, Index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     604             subarr = data
#     605             if data.dtype == object:
# --> 606                 subarr = maybe_infer_to_datetimelike(data)
#     607                 if (
#     608                     object_index
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value)
#    1180     if value.ndim != 1:
#    1181         # Caller is responsible
# -> 1182         raise ValueError(value.ndim)  # pragma: no cover
#    1183
#    1184     if not len(value):
#
# ValueError: 2

# %%
# One-hot encode categorical features (Sex, Embarked)
ohe = OneHotEncoder(drop='first', sparse_output=False)
encoded_categorical = pd.DataFrame(ohe.fit_transform(df[['Sex', 'Embarked']]),
                                   columns=ohe.get_feature_names_out(['Sex', 'Embarked']))

# %%
# Combine encoded categorical with numerical features
numerical_features = df[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].reset_index(drop=True)
final_features = pd.concat([numerical_features, encoded_categorical], axis=1)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(final_features, df[target], test_size=0.2, random_state=42)

# %%
# Linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Check model performance
print("Model coefficients:", model.coef_)
print("Model intercept:", model.intercept_)
# Out:
# Model coefficients: [-1.54120707e-01 -4.82943647e-03 -3.87580470e-02 -1.96778713e-02
#   3.50071828e-04 -5.11960419e-01 -2.20911792e-02 -7.32427949e-02
#   8.04811698e-02]
# Model intercept: 1.2871056145308335
